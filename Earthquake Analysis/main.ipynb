# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#                Origin Time  Latitude  Longitude  Depth  Magnitude  \
# 0  2021-07-31 09:43:23 IST     29.06      77.42    5.0        2.5
# 1  2021-07-30 23:04:57 IST     19.93      72.92    5.0        2.4
# 2  2021-07-30 21:31:10 IST     31.50      74.37   33.0        3.4
# 3  2021-07-30 13:56:31 IST     28.34      76.23    5.0        3.1
# 4  2021-07-30 07:19:38 IST     27.09      89.97   10.0        2.1
#
#                                Location
# 0          53km NNE of New Delhi, India
# 1  91km W of Nashik, Maharashtra, India
# 2   49km WSW of Amritsar, Punjab, India
# 3           50km SW of Jhajjar, Haryana
# 4            53km SE of Thimphu, Bhutan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2719 entries, 0 to 2718
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Origin Time  2719 non-null   object
#  1   Latitude     2719 non-null   float64
#  2   Longitude    2719 non-null   float64
#  3   Depth        2719 non-null   float64
#  4   Magnitude    2719 non-null   float64
#  5   Location     2719 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 127.6+ KB

# %%
df.describe()
# Out:
#           Latitude    Longitude        Depth    Magnitude
# count  2719.000000  2719.000000  2719.000000  2719.000000
# mean     29.939433    80.905638    53.400478     3.772196
# std       7.361564    10.139075    68.239737     0.768076
# min       0.120000    60.300000     0.800000     1.500000
# 25%      25.700000    71.810000    10.000000     3.200000
# 50%      31.210000    76.610000    15.000000     3.900000
# 75%      36.390000    92.515000    82.000000     4.300000
# max      40.000000    99.960000   471.000000     7.000000

# %% [markdown]
# Which countries have magnitude of 5.5?

# %%
df['Magnitude'].unique()
df['Location']
# Out:
# 0                            53km NNE of New Delhi, India
# 1                    91km W of Nashik, Maharashtra, India
# 2                     49km WSW of Amritsar, Punjab, India
# 3                             50km SW of Jhajjar, Haryana
# 4                              53km SE of Thimphu, Bhutan
#                               ...
# 2714    224km ESE of Diglipur, Andaman and Nicobar isl...
# 2715                    31km SW of Ukhrul, Manipur, India
# 2716                           28km WSW of Kolkata, India
# 2717                    35km SE of Imphal, Manipur, India
# 2718    137km N of Diglipur, Andaman and Nicobar islan...
# Name: Location, Length: 2719, dtype: object

# %%
countries=df.loc[df.Magnitude>5.5]

# %%
countries=countries['Location']

# %%
countries=(countries.to_list())
countries
# Out:
# ['173km ENE of Dushanbe, Tajikistan',
#  '770km NNE of Pangin, Arunachal Pradesh, India',
#  '402km SE of Changlang, Arunachal Pradesh, India',
#  '642km WSW of Kuala Lumpur, Malaysia',
#  '43km W of Tezpur, Assam, India',
#  '651km WSW of Kuala Lumpur, Malaysia',
#  '760km N of Lachung, Sikkim, India',
#  '459km NNW of Basar, Arunachal Pradesh, India',
#  '285km ENE of Fayzabad, Afghanistan',
#  '604km NNE of Kathmandu, Nepal',
#  '266km E of Portblair, Andaman and Nicobar island, India',
#  '264km E of Portblair, Andaman and Nicobar island, India',
#  '451km NE of Hanley, Jammu & Kashmir, India',
#  '117km SE of Champhai, Mizoram, India',
#  '163km NW of Yuksom, Sikkim, India',
#  '250km NNE of Fayzabad, Afghanistan',
#  '395km SSE of Bishkek, Kyrgyzstan',
#  '577km SSE of Campbell Bay, Andaman and Nicobar island, India',
#  '66km S of Fayzabad, Afghanistan',
#  '64km WSW of Rajouri, Jammu and Kashmir',
#  '109km NNW of Burma, Myanmar',
#  '77km SSW of Fayzabad, Afghanistan']

# %%
countries=" ".join(countries)
countries
# Out:
# '173km ENE of Dushanbe, Tajikistan 770km NNE of Pangin, Arunachal Pradesh, India 402km SE of Changlang, Arunachal Pradesh, India 642km WSW of Kuala Lumpur, Malaysia 43km W of Tezpur, Assam, India 651km WSW of Kuala Lumpur, Malaysia 760km N of Lachung, Sikkim, India 459km NNW of Basar, Arunachal Pradesh, India 285km ENE of Fayzabad, Afghanistan 604km NNE of Kathmandu, Nepal 266km E of Portblair, Andaman and Nicobar island, India 264km E of Portblair, Andaman and Nicobar island, India 451km NE of Hanley, Jammu & Kashmir, India 117km SE of Champhai, Mizoram, India 163km NW of Yuksom, Sikkim, India 250km NNE of Fayzabad, Afghanistan 395km SSE of Bishkek, Kyrgyzstan 577km SSE of Campbell Bay, Andaman and Nicobar island, India 66km S of Fayzabad, Afghanistan 64km WSW of Rajouri, Jammu and Kashmir 109km NNW of Burma, Myanmar 77km SSW of Fayzabad, Afghanistan'

# %%
import re
a=" ".join((re.findall('of\D*', countries)))
("".join(re.findall('[^of]',a)))
# Out:
# ' Dushanbe, Tajikistan   Pangin, Arunachal Pradesh, India   Changlang, Arunachal Pradesh, India   Kuala Lumpur, Malaysia   Tezpur, Assam, India   Kuala Lumpur, Malaysia   Lachung, Sikkim, India   Basar, Arunachal Pradesh, India   Fayzabad, Aghanistan   Kathmandu, Nepal   Prtblair, Andaman and Nicbar island, India   Prtblair, Andaman and Nicbar island, India   Hanley, Jammu & Kashmir, India   Champhai, Mizram, India   Yuksm, Sikkim, India   Fayzabad, Aghanistan   Bishkek, Kyrgyzstan   Campbell Bay, Andaman and Nicbar island, India   Fayzabad, Aghanistan   Rajuri, Jammu and Kashmir   Burma, Myanmar   Fayzabad, Aghanistan'

# %% [markdown]
# #New

# %%
df.head()
# Out:
#                Origin Time  Latitude  Longitude  Depth  Magnitude  \
# 0  2021-07-31 09:43:23 IST     29.06      77.42    5.0        2.5
# 1  2021-07-30 23:04:57 IST     19.93      72.92    5.0        2.4
# 2  2021-07-30 21:31:10 IST     31.50      74.37   33.0        3.4
# 3  2021-07-30 13:56:31 IST     28.34      76.23    5.0        3.1
# 4  2021-07-30 07:19:38 IST     27.09      89.97   10.0        2.1
#
#                                Location
# 0          53km NNE of New Delhi, India
# 1  91km W of Nashik, Maharashtra, India
# 2   49km WSW of Amritsar, Punjab, India
# 3           50km SW of Jhajjar, Haryana
# 4            53km SE of Thimphu, Bhutan

# %% [markdown]
# What is the maximum depth of the earthquake and where is it found?

# %%
df.Depth.max()
# Out:
# 471.0

# %%
df.Depth.unique()
# Out:
# array([  5. ,  33. ,  10. , 115. ,  28. , 160. ,  19. ,  50. , 100. ,
#         18. , 250. ,  40. ,  15. ,  23. , 110. , 200. ,  20. , 146. ,
#          8. ,  70. , 165. , 130. ,  37. ,  17. ,  90. , 167. ,  22. ,
#         14. ,  46. , 120. ,  45. ,  30. , 168. ,  65. ,  16. , 131. ,
#          7. ,  36. ,  47. ,  80. ,  63. , 150. , 135. ,  24. ,  59. ,
#         12. ,   3.4, 170. , 117. ,  52. ,  81. , 349. , 109. ,  34. ,
#         84. , 180. , 175. , 101. , 147. ,  82. , 174. , 108. ,  25. ,
#         13. ,   9. , 113. , 154. , 238. , 210. ,  74. ,  68. , 156. ,
#         27. ,  85. ,  93. , 136. ,  53.9,  75. ,  51. ,  26. ,  11. ,
#        158. , 125. ,  56. , 190. ,  35. , 225. ,  89. , 176. , 187. ,
#         39. ,  60. ,   6. ,  42. ,  79. , 140. ,  41. , 230. ,  97. ,
#         38. , 217. ,  48. ,  83. ,  94. , 155. , 105. ,  55. , 220. ,
#        266. ,  67. , 290. , 234. , 139. , 124. , 138. , 169. , 151. ,
# ...

# %%
max_depth=df.Depth.max()

# %%
temp=df.loc[df.Depth==max_depth]

# %%
temp['Location']
# Out:
# 2448    475km NNE of Kathmandu, Nepal
# Name: Location, dtype: object

# %%
temp['Magnitude']
# Out:
# 2448    4.6
# Name: Magnitude, dtype: float64

# %% [markdown]
# Where most of the earthquakes happen?

# %%
df["Location"].mode()
# Out:
# 0    93km W of Nashik, Maharashtra, India
# Name: Location, dtype: object

# %% [markdown]
# # Vizualize data

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.Magnitude, df.Latitude)
plt.xlabel('Magnitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# By the above scatter plot we can interpret that most of the earthquakes of Magnitude between 2 and 4.9 happen at latitude of 25 and 32.

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df, alpha=1, figsize=(15, 15))
# Out:
# array([[<AxesSubplot:xlabel='Latitude', ylabel='Latitude'>,
#         <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>,
#         <AxesSubplot:xlabel='Depth', ylabel='Latitude'>,
#         <AxesSubplot:xlabel='Magnitude', ylabel='Latitude'>],
#        [<AxesSubplot:xlabel='Latitude', ylabel='Longitude'>,
#         <AxesSubplot:xlabel='Longitude', ylabel='Longitude'>,
#         <AxesSubplot:xlabel='Depth', ylabel='Longitude'>,
#         <AxesSubplot:xlabel='Magnitude', ylabel='Longitude'>],
#        [<AxesSubplot:xlabel='Latitude', ylabel='Depth'>,
#         <AxesSubplot:xlabel='Longitude', ylabel='Depth'>,
#         <AxesSubplot:xlabel='Depth', ylabel='Depth'>,
#         <AxesSubplot:xlabel='Magnitude', ylabel='Depth'>],
#        [<AxesSubplot:xlabel='Latitude', ylabel='Magnitude'>,
#         <AxesSubplot:xlabel='Longitude', ylabel='Magnitude'>,
#         <AxesSubplot:xlabel='Depth', ylabel='Magnitude'>,
#         <AxesSubplot:xlabel='Magnitude', ylabel='Magnitude'>]],
# ...

# %%
df.corr()
# Out:
#            Latitude  Longitude     Depth  Magnitude
# Latitude   1.000000  -0.604389  0.307276   0.145171
# Longitude -0.604389   1.000000 -0.246407  -0.085008
# Depth      0.307276  -0.246407  1.000000   0.336975
# Magnitude  0.145171  -0.085008  0.336975   1.000000

# %%
df_numeric=df.select_dtypes(exclude='object')
plt.boxplot(df_numeric)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1285858f580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1285858fca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1285858f370>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x12858570160>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x12858570430>,
# ...
#  'means': []}

# %%
df['Latitude'].mode()
# Out:
# 0    36.5
# Name: Latitude, dtype: float64

# %%
fig=plt.figure()
plt.violinplot(df_numeric)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x12858c22770>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x12858c226b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x12858c23a30>,
#  'cbars': <matplotlib.collections.LineCollection at 0x12858c23e80>}

# %%
df.Latitude.max()

# %%
df.Magnitude.max()
