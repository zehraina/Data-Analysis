# %% [markdown]
# # What's done in data analysis?

# %% [raw]
# 1. Find the missing values.
# 2. Explore the numerical and/or categorical datatypes.
# 3. FInding the relationships between features.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv("zomato.csv", encoding='ISO 8859-1')

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
country_codes=pd.read_excel(r'C:\Users\inaze\Desktop\Data Science\Zomato Dataset Analysis\Country-Code.xlsx')

# %%
# pip install openpyxl

# %%
country_codes.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_final=pd.merge(df, country_codes, on="Country Code", how="left")

# %%
df_final['Country Code'].head()
# Out:
# 0    162
# 1    162
# 2    162
# 3    162
# 4    162
# Name: Country Code, dtype: int64

# %%
df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_final=pd.merge(df, country_codes, on="Country Code", how="left")

# %%
df_final['Country Code'].isnull().sum()
# Out:
# 0

# %%
country_names=df_final.Country.value_counts().index[:3]

# %%
county_val=df_final.Country.value_counts().values[:3]

# %%
plt.pie(county_val, labels=country_names, textprops={'fontsize': 10}, autopct='%.2f')
plt.show()

# %% [markdown]
# We can see here that most of the transactions are done in India, then United States and then United Kingdom.

# %%
df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings=df_final.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# What we can infer from the above df is:
#     when the ratings are b/w 1.8 to 2.4, they're considered to be poor.
#     when the ratings are b/w 2.5 to 3.4, they're considered to be average.
#     when the ratings are b/w 3.5 to 3.9, they're considered to be good.
#     when the ratings are above 4.5, they're considered to be excellent.

# %%
import seaborn as sns
from matplotlib.pyplot import figure

figure(figsize=(15, 6), dpi=80)

sns.barplot('Aggregate rating', 'Rating count', data=ratings, hue="Rating text",dodge=False, palette=['blue', 'red', 'orange', 'yellow', "green", "green"])
# Out:
# C:\Users\inaze\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating count'>

# %% [markdown]
# Observations:
# Max number of ratings are between 2.5 and 3.4.
# A large number of people haven't even rated.

# %%
sns.countplot(x="Rating text", data=ratings, palette=['blue', 'red', 'orange', 'yellow', "green", "green"])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='count'>

# %%
df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Q. Which country hasn't rated?

# %%
df_final[df_final['Rating color']=="White"].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# Observations:
#     The maximum number of people from India haven't rated.

# %% [markdown]
# Q. Which currency is used by which country?

# %%
df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
(df_final[['Currency', 'Country']].groupby(['Country', 'Currency'])).size().reset_index()
# np.unique(df[['Courses', 'Duration']].values)
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
Q. Which countries have only delivery options?
# Out:
# Object `options` not found.

# %%
df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df_final[df_final['Has Online delivery']=="Yes"].groupby('Country').size().reset_index()
# Out:
#   Country     0
# 0   India  2423
# 1     UAE    28

# %%
Observations:
    Only India and UAE have only delivery option available.
# Out:
#   Input In [110]
#     Observations:
#                  ^
# SyntaxError: invalid syntax

# %%
df_final[['Country','Has Online delivery']].groupby(['Country','Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
city_labels=df_final.City.value_counts().index
city_values=df_final.City.value_counts()

# %%
plt.pie(city_values[:5], labels=city_labels[:5],  autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20a93638f10>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '69%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14%'),
#   Text(0.47940246685229276, -0.36079533641101336, '14%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0%')])

# %% [markdown]
# Q. Find the top 10 cuisines.

# %%
df_final.head()
# Out:
#       Restaurant ID                   Restaurant Name  Country Code  \
# 0           6317637                  Le Petit Souffle           162
# 3013         310143                Naturals Ice Cream             1
# 3012       18418277                       MOB Brewpub             1
# 727           58268  The Fatty Bao - Asian Gastro Bar             1
# 728           51705                              Toit             1
#
#              City                                            Address  \
# 0     Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 3013    New Delhi      L-8, Outer Circle, Connaught Place, New Delhi
# 3012    New Delhi     M 44, Outer Circle, Connaught Place, New Delhi
# 727     Bangalore  610, 3rd Floor, 12th Main, Off 80 Feet Road, I...
# 728     Bangalore  298, Namma Metro Pillar 62, 100 Feet Road, Ind...
#
#                                        Locality  \
# 0     Century City Mall, Poblacion, Makati City
# ...

# %%
names=df_final.Cuisines.value_counts().index
counts=df_final.Cuisines.value_counts()
counts
# Out:
# North Indian                                  936
# North Indian, Chinese                         511
# Chinese                                       354
# Fast Food                                     354
# North Indian, Mughlai                         334
#                                              ...
# Kebab, Turkish Pizza, Dí_ner                    1
# Continental, Asian                              1
# Cafe, American, Italian, Continental            1
# Chinese, Thai, Japanese, Asian                  1
# American, Bakery, European, Burger, Fusion      1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
plt.pie(counts[:10], labels=names[:10],autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20a942b12d0>,
# ...
#  [Text(0.7383739846958008, 0.8153550507137645, 'North Indian'),
#   Text(-0.5794679314239953, 0.9349956772366362, 'North Indian, Chinese'),
#   Text(-1.067309479615702, 0.26617752482593154, 'Chinese'),
#   Text(-1.0185984499802057, -0.4152796620326146, 'Fast Food'),
#   Text(-0.5935788454809928, -0.9261015895664211, 'North Indian, Mughlai'),
#   Text(-0.005887079599915552, -1.0999842463843672, 'Cafe'),
#   Text(0.4842062514572988, -0.9876964645323336, 'Bakery'),
#   Text(0.808736477166136, -0.7456174022251013, 'North Indian, Mughlai, Chinese'),
#   Text(1.0055375294202338, -0.44597564611473206, 'Bakery, Desserts'),
#   Text(1.090298995560443, -0.14576728123927227, 'Street Food')],
#  [Text(0.4027494461977095, 0.4447391185711442, '27%'),
#   Text(-0.316073417140361, 0.5099976421290743, '15%'),
#   Text(-0.5821688070631101, 0.14518774081414446, '10%'),
#   Text(-0.5555991545346576, -0.22651617929051704, '10%'),
# ...
