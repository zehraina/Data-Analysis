# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\inaze\Desktop\Data Science\World Happiness Analysis\The Datasets\2015.csv")

# %%
len(df.columns)
# Out:
# 12

# %%
len(df)
# Out:
# 158

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.iloc[0]
# Out:
# Country                             Switzerland
# Region                           Western Europe
# Happiness Rank                                1
# Happiness Score                           7.587
# Standard Error                          0.03411
# Economy (GDP per Capita)                1.39651
# Family                                  1.34951
# Health (Life Expectancy)                0.94143
# Freedom                                 0.66557
# Trust (Government Corruption)           0.41978
# Generosity                              0.29678
# Dystopia Residual                       2.51738
# Name: 0, dtype: object

# %% [markdown]
# ## Here we can see that there are 12 columns and 158 rows.

# %% [markdown]
# ## Now lets take a look at how the happiness score is distributed

# %%
df['Happiness Score'].describe()
# Out:
# count    158.000000
# mean       5.375734
# std        1.145010
# min        2.839000
# 25%        4.526000
# 50%        5.232500
# 75%        6.243750
# max        7.587000
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(9, 8))
sns.distplot(df['Happiness Score'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# C:\Users\inaze\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Numerical Data Distribution

# %% [markdown]
# ## listing all the types of the data from our dataset.

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('int64'), dtype('O'), dtype('float64')]

# %%
df_num=df.select_dtypes(include=['int64', 'float64' ])
df_ob=df.select_dtypes(include=['O'])

# %%
df_num.head()
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
df_num.tail()
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# ...

# %%
df_ob.head()
# Out:
#        Country          Region
# 0  Switzerland  Western Europe
# 1      Iceland  Western Europe
# 2      Denmark  Western Europe
# 3       Norway  Western Europe
# 4       Canada   North America

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# ## Finding correlations; we'll look for the features that are strongly correlated to the Happiness Rank of the countries.

# %%
golden_features=df_num.corr()['Happiness Rank']

# %%
golden_features
# Out:
# Happiness Rank                   1.000000
# Happiness Score                 -0.992105
# Standard Error                   0.158516
# Economy (GDP per Capita)        -0.785267
# Family                          -0.733644
# Health (Life Expectancy)        -0.735613
# Freedom                         -0.556886
# Trust (Government Corruption)   -0.372315
# Generosity                      -0.160142
# Dystopia Residual               -0.521999
# Name: Happiness Rank, dtype: float64

# %%
type(golden_features)
# Out:
# pandas.core.series.Series

# %%
df_num.plot(x="Happiness Rank", y=["Health (Life Expectancy)"],
        kind="line", figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_num.plot(x="Happiness Score", y=["Standard Error"],
        kind="line", figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %%
df_num.plot(x="Happiness Rank", y=["Family"],
        kind="line", figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %%
df_num.plot(x="Happiness Rank", y=["Economy (GDP per Capita)"],
        kind="line", figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %%
df_num.plot(x="Happiness Rank", y=["Family"],
        kind="line", figsize=(10, 10))

# %%
df_num.plot(x="Happiness Rank", y=["Trust (Government Corruption)"],
        kind="line", figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %%
golden_features_list = golden_features[abs(golden_features) > 0.5].sort_values(ascending=False)

# %%
golden_features_list
# Out:
# Happiness Score             1.000000
# Economy (GDP per Capita)    0.780966
# Family                      0.740605
# Health (Life Expectancy)    0.724200
# Freedom                     0.568211
# Dystopia Residual           0.530474
# Happiness Rank             -0.992105
# Name: Happiness Score, dtype: float64

# %% [markdown]
# # Analysing the outliers

# %% [markdown]
# We now have a list of strongly correlated values but this list is incomplete as we know that correlation is affected by outliers. So we could proceed as follow:
#
# 1. Plot the numerical features and see which ones have very few or explainable outliers.
#
# 2. Remove the outliers from these features and see which one can have a good correlation without their outliers.

# %%
df_num.columns
# Out:
# Index(['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
# from pandas.plotting import scatter_matrix
# attributes=['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual']
# scatter_matrix(df_num[attributes], figsize=(30,25))

# %% [markdown]
# ## Plotting in two ways the correlations of Happiness Rank with the other features.

# %%
sns.set(font_scale=3)
p=sns.pairplot(data=df_num, height=4)
p

# %%
sns.set(font_scale=1)
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars=df_num.columns[i:i+5],
                y_vars=['Happiness Rank'])

# %% [markdown]
# # Observations -

# %% [markdown]
# From the above figures, one can infer that all the features are negatively correlated with Happiness Rank.
